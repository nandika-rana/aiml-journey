# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns #to use its dataset

plt.style.use('default')

# %%
#plotting a simple function
price = [48000,54000,57000,49000,47000,45000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year,price) #2Dline plot

# %%
#from a pandas dataframe
batsman = pd.read_csv('sharma-kohli.csv')
print(batsman)

plt.plot(batsman['index'],batsman['V Kohli'])
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
#plotting multiple plots
plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])

# %%
# labels title
plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])

plt.title('Rohit Sharma vs Virat Kohli Career Comparison')
plt.xlabel('Seanson')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
#color(hex) and line(width and style) and marker(size) 
plt.plot(batsman['index'],batsman['V Kohli'],color='green')
plt.plot(batsman['index'],batsman['RG Sharma'],color='#941982')

plt.title('Rohit Sharma vs Virat Kohli Career Comparison')
plt.xlabel('Seanson')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='solid', linewidth=3)
plt.plot(batsman['index'],batsman['RG Sharma'],color='#941982',linestyle='dashdot', linewidth=2)

plt.title('Rohit Sharma vs Virat Kohli Career Comparison')
plt.xlabel('Seanson')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='solid', linewidth=3, marker='.', markersize=10)
plt.plot(batsman['index'],batsman['RG Sharma'],color='#941982',linestyle='dashdot', linewidth=2, marker='o')

plt.title('Rohit Sharma vs Virat Kohli Career Comparison')
plt.xlabel('Seanson')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
#legend -> location
#color(hex) and line(width and style) and marker(size) 
plt.plot(batsman['index'],batsman['V Kohli'],color='green',label='Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color='#941982',label='Rohit')

plt.title('Rohit Sharma vs Virat Kohli Career Comparison')
plt.xlabel('Seanson')
plt.ylabel('Runs Scored')

plt.legend(loc='upper right')

# %%
#limiting axes
price = [48000,54000,57000,49000,47000,45000,4500000]
year = [2015,2016,2017,2018,2019,2020,2021]

plt.plot(year,price) #2Dline plot
plt.ylim(0,75000)
plt.xlim(2017,2019)
# Out:
# (2017.0, 2019.0)

# %%
#grid
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='solid', linewidth=3,marker='D')
plt.plot(batsman['index'],batsman['RG Sharma'],color='#941982',linestyle='dashdot', linewidth=2,marker='D')

plt.title('Rohit Sharma vs Virat Kohli Career Comparison')
plt.xlabel('Seanson')
plt.ylabel('Runs Scored')

plt.grid()

# %%
#show
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='solid', linewidth=3,marker='D')
plt.plot(batsman['index'],batsman['RG Sharma'],color='#941982',linestyle='dashdot', linewidth=2,marker='D')

plt.title('Rohit Sharma vs Virat Kohli Career Comparison')
plt.ylabel('Runs Scored')

plt.grid()
